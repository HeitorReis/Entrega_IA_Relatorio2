# %%
# Array manipulation
import numpy as np

# Random variables generator
import random as rand

# data processing / .csv manipulation and reading
import pandas as pd


# Data visualization
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style

# Algorithms / AI
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth, association_rules

# %%
rules = pd.read_csv('rules.csv') # Objects are loaded with infos from .csv
rules
# Out:
#      Unnamed: 0                       antecedents  \
# 0            12             frozenset({'Mgrd06'})
# 1            16             frozenset({'Mgrd06'})
# 2            20             frozenset({'Mgrd06'})
# 3            24            frozenset({'Mgrd101'})
# 4            25             frozenset({'Mgrd08'})
# ..          ...                               ...
# 314         801             frozenset({'Mgrd01'})
# 315         809            frozenset({'Mgrd035'})
# 316         816  frozenset({'Mgrd01', 'Mgrd035'})
# 317         820             frozenset({'Mgrd01'})
# 318         823            frozenset({'Mgrd035'})
#
#                                       consequents  antecedent support  \
# 0                           frozenset({'Mgrd08'})            0.351526
# 1                 frozenset({'Mgrd19', 'Mgrd08'})            0.351526
# 2                frozenset({'Mgrd212', 'Mgrd08'})            0.351526
# 3                           frozenset({'Mgrd08'})            0.272890
# 4                          frozenset({'Mgrd101'})            0.321724
# ..                                            ...                 ...
# 314             frozenset({'Mgrd047', 'Mgrd044'})            0.523519
# 315             frozenset({'Mgrd047', 'Mgrd044'})            0.426391
# 316             frozenset({'Mgrd047', 'Mgrd044'})            0.426391
# 317  frozenset({'Mgrd047', 'Mgrd044', 'Mgrd035'})            0.523519
# 318   frozenset({'Mgrd01', 'Mgrd044', 'Mgrd047'})            0.426391
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 0              0.321724  0.265530    0.755363  2.347863  0.152435    2.772579
# 1              0.251885  0.212926    0.605720  2.404748  0.124382    1.897421
# 2              0.283124  0.237343    0.675179  2.384747  0.137817    2.206987
# 3              0.321724  0.272890    1.000000  3.108259  0.185095         inf
# 4              0.272890  0.272890    0.848214  3.108259  0.185095    4.790369
# ..                  ...       ...         ...       ...       ...         ...
# 314            0.215619  0.215619    0.411866  1.910151  0.102739    1.333676
# 315            0.215619  0.202154    0.474105  2.198806  0.110216    1.491516
# 316            0.215619  0.202154    0.474105  2.198806  0.110216    1.491516
# 317            0.202154  0.202154    0.386145  1.910151  0.096323    1.299731
# 318            0.215619  0.202154    0.474105  2.198806  0.110216    1.491516
#
#      zhangs_metric
# 0         0.885279
# 1         0.900816
# 2         0.895438
# 3         0.932840
# 4         1.000000
# ..             ...
# 314       1.000000
# 315       0.950487
# 316       0.950487
# 317       1.000000
# 318       0.950487
#
# [319 rows x 11 columns]

# %%
rules.drop('Unnamed: 0', axis='columns', inplace=True)

# %%
for column in ['antecedents', 'consequents']:
  for index, row in enumerate( rules[column] ):
    
    rules.loc[index, column] = row.replace('frozenset({', '').replace('})', '').replace(' ', '')

rules
# Out:
#             antecedents                    consequents  antecedent support  \
# 0              'Mgrd06'                       'Mgrd08'            0.351526
# 1              'Mgrd06'              'Mgrd19','Mgrd08'            0.351526
# 2              'Mgrd06'             'Mgrd212','Mgrd08'            0.351526
# 3             'Mgrd101'                       'Mgrd08'            0.272890
# 4              'Mgrd08'                      'Mgrd101'            0.321724
# ..                  ...                            ...                 ...
# 314            'Mgrd01'            'Mgrd047','Mgrd044'            0.523519
# 315           'Mgrd035'            'Mgrd047','Mgrd044'            0.426391
# 316  'Mgrd01','Mgrd035'            'Mgrd047','Mgrd044'            0.426391
# 317            'Mgrd01'  'Mgrd047','Mgrd044','Mgrd035'            0.523519
# 318           'Mgrd035'   'Mgrd01','Mgrd044','Mgrd047'            0.426391
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 0              0.321724  0.265530    0.755363  2.347863  0.152435    2.772579
# 1              0.251885  0.212926    0.605720  2.404748  0.124382    1.897421
# 2              0.283124  0.237343    0.675179  2.384747  0.137817    2.206987
# 3              0.321724  0.272890    1.000000  3.108259  0.185095         inf
# 4              0.272890  0.272890    0.848214  3.108259  0.185095    4.790369
# ..                  ...       ...         ...       ...       ...         ...
# 314            0.215619  0.215619    0.411866  1.910151  0.102739    1.333676
# 315            0.215619  0.202154    0.474105  2.198806  0.110216    1.491516
# 316            0.215619  0.202154    0.474105  2.198806  0.110216    1.491516
# 317            0.202154  0.202154    0.386145  1.910151  0.096323    1.299731
# 318            0.215619  0.202154    0.474105  2.198806  0.110216    1.491516
#
#      zhangs_metric
# 0         0.885279
# 1         0.900816
# 2         0.895438
# 3         0.932840
# 4         1.000000
# ..             ...
# 314       1.000000
# 315       0.950487
# 316       0.950487
# 317       1.000000
# 318       0.950487
#
# [319 rows x 10 columns]

# %%
rules.loc[101, ['antecedents', 'consequents']]
# Out:
# antecedents             'Mgrd031','Mgrd035'
# consequents    'Mgrd047','Mgrd212','Mgrd01'
# Name: 101, dtype: object

# %%
print(f'''
This:\t\t{rules.values[100][0]+' and '+rules.values[100][1]}
Becomes this: \t{sorted((rules.values[100][0]+','+rules.values[100][1]).split(','))}

This:\t\t{rules.values[101][0]+' and '+rules.values[101][1]}
Becomes this: \t{sorted((rules.values[101][0]+','+rules.values[101][1]).split(','))}

Is equal: {sorted((rules.values[101][0]+','+rules.values[101][1]).split(',')) == sorted((rules.values[100][0]+','+rules.values[100][1]).split(','))}.''')
# Out:
# This:		'Mgrd01','Mgrd031' and 'Mgrd047','Mgrd035','Mgrd212'
# Becomes this: 	["'Mgrd01'", "'Mgrd031'", "'Mgrd035'", "'Mgrd047'", "'Mgrd212'"]
#
# This:		'Mgrd031','Mgrd035' and 'Mgrd047','Mgrd212','Mgrd01'
# Becomes this: 	["'Mgrd01'", "'Mgrd031'", "'Mgrd035'", "'Mgrd047'", "'Mgrd212'"]
#
# Is equal: True.

# %%
rules.loc[:, 'zhangs_metric'].idxmax()
# Out:
# 18

# %%
# Now, the only thing that matters to understanding the association rules
# above is a list that shortens the association rules that are repeated.

def pruneDataFrame( df ):
  
  organized_rules = []
  
  for index, row in enumerate( df.values ):
    
    organized_rules.append( sorted((row[0]+','+row[1]).split(',')) )
  
  duplicates = []
  
  for rule_index, rule in enumerate(organized_rules):
    duplicates.append(list())
    for comp_index, comparator in enumerate(organized_rules):
      if comparator == rule:
        duplicates[rule_index].append(comp_index)
  
  max_set = set()
  
  for dups in duplicates:
    if len(dups) > 1:
      
      max_index = df.loc[ dups, 'zhangs_metric'].idxmax()

    else:
      max_index = dups[0]
    
    max_set.add(max_index)
  
  return df.loc[ list(max_set) ]

pruned_rules = pruneDataFrame( rules )

# %%
pruned_rules.shape
# Out:
# (113, 10)

# %%
filename = f'pruned-rules.xlsx'
with open(filename, 'w') as output_handle: # Save as .csv for visualization
  pruned_rules.to_excel(filename, columns=pruned_rules.columns)
# Out:
# c:\Users\tobie\.conda\envs\COPE\Lib\site-packages\openpyxl\packaging\core.py:99: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   now = datetime.datetime.utcnow()
# c:\Users\tobie\.conda\envs\COPE\Lib\site-packages\openpyxl\writer\excel.py:292: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   workbook.properties.modified = datetime.datetime.utcnow()

# %%
indexes = pd.read_csv('indexes.csv')

# %%
indexes
# Out:
#                                                 param1  \
# 0    O município foi atingido pela seca nos últimos...
# 1    O município foi atingido pela seca nos últimos...
# 2    O município foi atingido pela seca nos últimos...
# 3    O município foi atingido pela seca nos últimos...
# 4    O município foi atingido pela seca nos últimos...
# ..                                                 ...
# 155             Atividades de proteção de defesa civil
# 156             Atividades de proteção de defesa civil
# 157             Atividades de proteção de defesa civil
# 158             Atividades de proteção de defesa civil
# 159             Atividades de proteção de defesa civil
#
#                                                 param2              param3  \
# 0                                                  NaN                 NaN
# 1    Ano em que aconteceu a seca de maior impacto p...                 NaN
# 2    No ano de seca de maior impacto para o municíp...  Perdas financeiras
# 3    No ano de seca de maior impacto para o municíp...      Perdas humanas
# 4    No ano de seca de maior impacto para o municíp...   Perdas de animais
# ..                                                 ...                 ...
# 155  Campanhas para conscientizar a população sobre...                 NaN
# 156  Capacitação de profissionais de proteção e def...                 NaN
# 157                                 Formação de NUDECs                 NaN
# 158                                Nenhuma das citadas                 NaN
# 159                                  Não sabe informar                 NaN
#
#         code
# 0     MGRD01
# 1     MGRD02
# 2    MGRD031
# 3    MGRD032
# 4    MGRD033
# ..       ...
# 155  MGRD235
# 156  MGRD236
# 157  MGRD237
# 158  MGRD238
# 159  MGRD239
#
# [160 rows x 4 columns]

# %%
for row in pruned_rules['antecedents']:
  print(row)
# Out:
# 'Mgrd06'
# 'Mgrd06'
# 'Mgrd06'
# 'Mgrd08'
# 'Mgrd06'
# 'Mgrd08'
# 'Mgrd08'
# 'Mgrd08'
# 'Mgrd06'
# 'Mgrd08'
# 'Mgrd08'
# 'Mgrd101'
# 'Mgrd08'
# 'Mgrd08'
# 'Mgrd08'
# 'Mgrd101'
# 'Mgrd08'
# 'Mgrd181'
# 'Mgrd181'
# 'Mgrd208'
# 'Mgrd208'
# 'Mgrd208'
# 'Mgrd208'
# 'Mgrd208'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd031'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd031'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd031'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd031'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd01'
# 'Mgrd11'
# 'Mgrd06'
# 'Mgrd11'
# 'Mgrd11'
# 'Mgrd11'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd01','Mgrd212'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd01','Mgrd212'
# 'Mgrd035','Mgrd212'
# 'Mgrd01'
# 'Mgrd01','Mgrd212'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd031'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd031'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd01'
# 'Mgrd01'
# 'Mgrd035'
# 'Mgrd01'

# %%
for code_index, code in enumerate( indexes['code'] ):
  for col_name in ['antecedents', 'consequents']:
    for row_index, row in enumerate( pruned_rules[col_name] ):
      
      code_name = str(indexes.loc[code_index, 'param1'])
      code_name = code_name+' '+str(indexes.loc[code_index, 'param2'])
      code_name = code_name+' '+str(indexes.loc[code_index, 'param3'])
      
      if type(row) == type(0.55):
        print(row, pruned_rules.index[row_index])
      if "'"+code.title()+"'" in row:
        pruned_rules.loc[pruned_rules.index[row_index], col_name] = row.replace(code.title(), code_name)

# %%
pruned_rules['consequents'][2]
# Out:
# "'Em relação à gestão de riscos e de desastres, existe no município Coordenação Municipal de Proteção e Defesa Civil (COMPDEC) ou órgão similar nan','O município foi atingido por enchentes ou inundações graduais nos últimos 4 anos nan nan'"

# %%
filename = f'pruned-rules_labeled.xlsx'
with open(filename, 'w') as output_handle: # Save as .csv for visualization
  pruned_rules.to_excel(filename, columns=pruned_rules.columns)
# Out:
# c:\Users\tobie\.conda\envs\COPE\Lib\site-packages\openpyxl\packaging\core.py:99: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   now = datetime.datetime.utcnow()
# c:\Users\tobie\.conda\envs\COPE\Lib\site-packages\openpyxl\writer\excel.py:292: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   workbook.properties.modified = datetime.datetime.utcnow()

# %%
pruned_rules
# Out:
#                                            antecedents  \
# 0    'O município foi atingido por alagamentos nos ...
# 1    'O município foi atingido por alagamentos nos ...
# 2    'O município foi atingido por alagamentos nos ...
# 4    'O município foi atingido por enchentes ou inu...
# 5    'O município foi atingido por alagamentos nos ...
# ..                                                 ...
# 302  'O município foi atingido pela seca nos último...
# 312  'O município foi atingido pela seca nos último...
# 314  'O município foi atingido pela seca nos último...
# 315  'O município foi atingido pela seca nos último...
# 317  'O município foi atingido pela seca nos último...
#
#                                            consequents  antecedent support  \
# 0    'O município foi atingido por enchentes ou inu...            0.351526
# 1    'Em relação a gestão de riscos de desastres de...            0.351526
# 2    'Em relação à gestão de riscos e de desastres,...            0.351526
# 4    'No ano de enchente ou inundação gradual de ma...            0.321724
# 5    'No ano de enchente ou inundação gradual de ma...            0.351526
# ..                                                 ...                 ...
# 302  'O município foi atingido pela seca nos último...            0.426391
# 312  'O município foi atingido pela seca nos último...            0.523519
# 314  'O município foi atingido pela seca nos último...            0.523519
# 315  'O município foi atingido pela seca nos último...            0.426391
# 317  'O município foi atingido pela seca nos último...            0.523519
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 0              0.321724  0.265530    0.755363  2.347863  0.152435    2.772579
# 1              0.251885  0.212926    0.605720  2.404748  0.124382    1.897421
# 2              0.283124  0.237343    0.675179  2.384747  0.137817    2.206987
# 4              0.272890  0.272890    0.848214  3.108259  0.185095    4.790369
# 5              0.272890  0.233214    0.663432  2.431129  0.137286    2.160365
# ..                  ...       ...         ...       ...       ...         ...
# 302            0.220108  0.207720    0.487158  2.213270  0.113868    1.520726
# 312            0.207720  0.207720    0.396776  1.910151  0.098975    1.313410
# 314            0.215619  0.215619    0.411866  1.910151  0.102739    1.333676
# 315            0.215619  0.202154    0.474105  2.198806  0.110216    1.491516
# 317            0.202154  0.202154    0.386145  1.910151  0.096323    1.299731
#
#      zhangs_metric
# 0         0.885279
# 1         0.900816
# 2         0.895438
# 4         1.000000
# 5         0.907775
# ..             ...
# 302       0.955669
# 312       1.000000
# 314       1.000000
# 315       0.950487
# 317       1.000000
#
# [113 rows x 10 columns]
